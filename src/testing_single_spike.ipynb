# %% [markdown]
# # This notebook walks through recording extracellular voltage using the simulator

# %%
# Imports and loading of NEURON dll
import numpy as np
from neuron import h
import simulation as sim
import matplotlib.pyplot as plt
import extracellular as ex
import helperFuncs as hf

# %% [markdown]
# ## Step 1: Setup simualted cell

# %% [markdown]
# ### Hard reset to delete any lingering segments

# %%
# clear all NEURON sims. Required if you are going to be running many exps
#  in Jupyter notebooks.
for sec in h.allsec():
   h.delete_section(sec=sec)

# %% [markdown]
# ### Build a cell, point to the params file of interest

# %%
# Code to setup a single simulated RGC
# Default params file located at: 'cell_param_files/params_35.csv'
RGC = sim.Local_Cell()
filename = 'cell_param_files/params_35_v2.csv'
RGC.build_cell(filename,'mammalian_spike_35')
# Out:
# After any change to cell geometry or nseg, be sure to invoke setpointers()

# %% [markdown]
# ### Output simple facts: (x,y,z) of soma center and all compartments

# %%
# print out where the center of the soma is located and shift if needed
#  Note, behind the scenes this is shifting all simualted compartments by 
#  the necessary x,y,z transforms to get the cell to the right spot 
print('Current soma center is located at: ', RGC.soma_center) # units: [um]

RGC.shift_cell_x_y_z(0,0,0)
print('New soma center is located at: ', RGC.soma_center)
# Out:
# Current soma center is located at:  [-11.9399995803833, 0.0, 10.0]
# New soma center is located at:  [0.0, 0.0, 0.0]

# %%
# Code to traverse through all sections and segments of a cell. This is very
#  useful for debugging and probing different features (membrane voltage, 
#  currents, channel dynamics) at each segment. It also helps to understand 
#  how the cell is layed out in space. 
for sec in RGC.section_list: 
    for seg in sec:
        print(seg)
        print('Segment coordinates: ', seg.x_xtra, seg.y_xtra, seg.z_xtra)
# Out:
# Cell[0].soma(0.1)
# Segment coordinates:  0.0 0.0 -8.0
# Cell[0].soma(0.3)
# Segment coordinates:  0.0 0.0 -3.999999999999999
# Cell[0].soma(0.5)
# Segment coordinates:  0.0 0.0 2.220446049250313e-15
# Cell[0].soma(0.7)
# Segment coordinates:  0.0 0.0 4.000000000000002
# Cell[0].soma(0.9)
# Segment coordinates:  0.0 0.0 8.0
# Cell[0].dend[0](0.125)
# Segment coordinates:  8.244684656136952 4.3437302051977404 -4.9695614754626245
# Cell[0].dend[0](0.375)
# Segment coordinates:  6.254054426174526 8.931190710960653 -10.908684426387872
# Cell[0].dend[0](0.625)
# Segment coordinates:  4.129450511405039 13.615720913606317 -16.601027853265297
# Cell[0].dend[0](0.875)
# Segment coordinates:  -0.36188830850202386 19.38462634076912 -17.39469860944437
# Cell[0].dend[50](0.5)
# Segment coordinates:  -4.945000171661377 19.614999771118164 -17.5
# Cell[0].dend[52](0.25)
# Segment coordinates:  -8.250492630372461 16.439785067507984 -17.5
# Cell[0].dend[52](0.75)
# Segment coordinates:  -11.842476772282906 13.165312943882286 -17.5
# Cell[0].dend[54](0.25)
# Segment coordinates:  -14.872632748139528 10.02235139653135 -17.5
# Cell[0].dend[54](0.75)
# Segment coordinates:  -16.155281183601787 6.37728088633366 -17.5
# Cell[0].dend[78](0.166667)
# Segment coordinates:  -19.223448698005203 4.157133136996653 -17.5
# Cell[0].dend[78](0.5)
# Segment coordinates:  -24.771705020822544 2.832073840161795 -17.0
# Cell[0].dend[78](0.833333)
# Segment coordinates:  -29.796077507721513 0.3003226258896131 -16.0
# Cell[0].dend[80](0.1)
# Segment coordinates:  -35.600904354378116 1.0501807217006545 -16.0
# Cell[0].dend[80](0.3)
# Segment coordinates:  -42.65204260479453 2.822985840297117 -16.0
# Cell[0].dend[80](0.5)
# Segment coordinates:  -49.43731654420442 0.08304879719842498 -16.0
# Cell[0].dend[80](0.7)
# Segment coordinates:  -55.454973222451045 -1.6819672671199837 -15.133879430696236
# Cell[0].dend[80](0.9)
# Segment coordinates:  -62.49821802664272 -2.2001366569025524 -15.5
# Cell[0].dend[79](0.166667)
# Segment coordinates:  -34.6812532621464 -3.338273154004481 -16.5
# Cell[0].dend[79](0.5)
# Segment coordinates:  -40.60821407327795 -7.573755308273546 -16.5
# Cell[0].dend[79](0.833333)
# Segment coordinates:  -45.6670975219801 -11.68193496571848 -17.5
# Cell[0].dend[55](0.166667)
# Segment coordinates:  -14.767402620462592 2.3152546636581746 -17.5
# Cell[0].dend[55](0.5)
# Segment coordinates:  -13.036242433825436 -2.4925467589743535 -17.5
# Cell[0].dend[55](0.833333)
# Segment coordinates:  -12.187826008995202 -7.385225306531359 -18.0
# Cell[0].dend[69](0.166667)
# Segment coordinates:  -14.262559748330894 -10.922269412543598 -18.0
# Cell[0].dend[69](0.5)
# Segment coordinates:  -19.246043853999367 -13.062490630745234 -18.5
# Cell[0].dend[69](0.833333)
# Segment coordinates:  -23.15247913898546 -16.797041587753398 -18.0
# Cell[0].dend[75](0.5)
# Segment coordinates:  -24.37097608100783 -21.274934355231004 -18.0
# Cell[0].dend[77](0.5)
# Segment coordinates:  -22.118056752636676 -23.06097246291506 -17.5
# Cell[0].dend[76](0.25)
# Segment coordinates:  -23.904510465555802 -24.495216339083377 -17.71830029649228
# Cell[0].dend[76](0.75)
# Segment coordinates:  -24.249070012778944 -27.569737448345236 -18.0
# Cell[0].dend[70](0.125)
# Segment coordinates:  -28.630321438861884 -19.134433352346345 -17.5
# Cell[0].dend[70](0.375)
# Segment coordinates:  -34.85669847323415 -22.130679496105184 -17.5
# Cell[0].dend[70](0.625)
# Segment coordinates:  -38.91463611688563 -26.98337264830429 -16.5
# Cell[0].dend[70](0.875)
# Segment coordinates:  -44.12745936055104 -32.650218900289616 -16.5
# Cell[0].dend[74](0.125)
# Segment coordinates:  -43.5690766416554 -36.85235830786685 -17.0
# Cell[0].dend[74](0.375)
# Segment coordinates:  -41.260249006502505 -41.64440187986547 -16.732507049989913
# Cell[0].dend[74](0.625)
# Segment coordinates:  -41.32444110603881 -47.59086225710616 -18.5
# Cell[0].dend[74](0.875)
# Segment coordinates:  -42.623959401928 -53.33054135469531 -18.0
# Cell[0].dend[71](0.25)
# Segment coordinates:  -48.40779567689327 -36.06558769557633 -17.0
# Cell[0].dend[71](0.75)
# Segment coordinates:  -51.995499643756816 -37.85296388722376 -16.5
# Cell[0].dend[73](0.1)
# Segment coordinates:  -57.942219770270356 -36.62371730754017 -16.0
# Cell[0].dend[73](0.3)
# Segment coordinates:  -65.57607175327429 -38.299890100948076 -16.0
# Cell[0].dend[73](0.5)
# Segment coordinates:  -73.76099971475908 -37.560930224480124 -16.0
# Cell[0].dend[73](0.7)
# Segment coordinates:  -81.49885673298942 -37.1059143639256 -15.0
# Cell[0].dend[73](0.9)
# Segment coordinates:  -89.37951678853985 -39.14384647026456 -14.5
# Cell[0].dend[72](0.166667)
# Segment coordinates:  -54.96759663979672 -40.83953388678309 -16.5
# Cell[0].dend[72](0.5)
# Segment coordinates:  -57.24325185481789 -44.95448102984977 -15.519936356814796
# Cell[0].dend[72](0.833333)
# Segment coordinates:  -60.110382221758115 -49.15638974787183 -16.0
# Cell[0].dend[56](0.25)
# Segment coordinates:  -10.413352768107682 -12.07073872961984 -18.0
# Cell[0].dend[56](0.75)
# Segment coordinates:  -7.563669638332266 -16.113945260836218 -18.5
# Cell[0].dend[66](0.166667)
# Segment coordinates:  -3.396850315885718 -17.373228314784093 -18.0
# Cell[0].dend[66](0.5)
# Segment coordinates:  1.1845963220071292 -14.384521299443565 -18.0
# Cell[0].dend[66](0.833333)
# Segment coordinates:  5.485276611583824 -12.207786670763086 -18.500000000000004
# Cell[0].dend[68](0.125)
# Segment coordinates:  10.34468246162424 -7.86056987238287 -17.5
# Cell[0].dend[68](0.375)
# Segment coordinates:  15.960331387904347 -3.015550231950055 -17.5
# Cell[0].dend[68](0.625)
# Segment coordinates:  21.35409338372072 3.113531214251295 -17.5
# Cell[0].dend[68](0.875)
# Segment coordinates:  28.152593020801405 7.972924188402883 -17.5
# Cell[0].dend[67](0.166667)
# Segment coordinates:  5.943821611248612 -7.15808359610742 -18.0
# Cell[0].dend[67](0.5)
# Segment coordinates:  8.719726435715453 -0.22933159184084012 -18.0
# Cell[0].dend[67](0.833333)
# Segment coordinates:  12.505699407831736 6.680032433516914 -18.0
# Cell[0].dend[57](0.166667)
# Segment coordinates:  -6.885962931500867 -20.542380383874598 -18.0
# Cell[0].dend[57](0.5)
# Segment coordinates:  -7.235635859080722 -25.48615739218579 -18.5
# Cell[0].dend[57](0.833333)
# Segment coordinates:  -7.716815068813098 -30.257379978233857 -19.0
# Cell[0].dend[61](0.25)
# Segment coordinates:  -9.640990452164342 -35.2975780084436 -20.0
# Cell[0].dend[61](0.75)
# Segment coordinates:  -14.894104079154769 -39.285167527337435 -19.5
# Cell[0].dend[63](0.125)
# Segment coordinates:  -20.94870297633645 -42.70948424340567 -19.5
# Cell[0].dend[63](0.375)
# Segment coordinates:  -26.64064052970513 -46.90785273520728 -19.5
# Cell[0].dend[63](0.625)
# Segment coordinates:  -31.67795338109754 -51.67192885094319 -19.5
# Cell[0].dend[63](0.875)
# Segment coordinates:  -36.01115074898051 -56.99098732409337 -19.5
# Cell[0].dend[65](0.125)
# Segment coordinates:  -40.034823004851276 -59.262588748525175 -19.0
# Cell[0].dend[65](0.375)
# Segment coordinates:  -46.59322621032217 -59.76757928607051 -19.5
# Cell[0].dend[65](0.625)
# Segment coordinates:  -50.68922812774052 -64.74476276364743 -18.861549237683004
# Cell[0].dend[65](0.875)
# Segment coordinates:  -55.88738749329137 -69.62774233721402 -19.0
# Cell[0].dend[64](0.166667)
# Segment coordinates:  -37.85535908297761 -63.21325918703253 -19.0
# Cell[0].dend[64](0.5)
# Segment coordinates:  -39.95196407256228 -69.37604309335202 -20.0
# Cell[0].dend[64](0.833333)
# Segment coordinates:  -42.852900093038926 -75.12555999606494 -20.5
# Cell[0].dend[62](0.0833333)
# Segment coordinates:  -16.866466852375645 -45.1564823079908 -20.0
# Cell[0].dend[62](0.25)
# Segment coordinates:  -15.658092460822058 -51.90943277525557 -20.0
# Cell[0].dend[62](0.416667)
# Segment coordinates:  -12.24754330619401 -58.29766652868513 -20.5
# Cell[0].dend[62](0.583333)
# Segment coordinates:  -12.791219634864788 -65.04384845290114 -21.0
# Cell[0].dend[62](0.75)
# Segment coordinates:  -11.498990992388656 -71.85918880818133 -21.0
# Cell[0].dend[62](0.916667)
# Segment coordinates:  -10.78300670383399 -78.94717772082 -21.5
# Cell[0].dend[58](0.25)
# Segment coordinates:  -7.4191785362776255 -34.75777079170297 -20.5
# Cell[0].dend[58](0.75)
# Segment coordinates:  -5.991934868438408 -39.95480498060829 -21.0
# Cell[0].dend[60](0.166667)
# Segment coordinates:  -5.699147715735242 -44.78608615494508 -21.5
# Cell[0].dend[60](0.5)
# Segment coordinates:  -7.191396778599831 -49.85850142806496 -21.0
# Cell[0].dend[60](0.833333)
# Segment coordinates:  -9.278138007731805 -54.852868995407704 -20.5
# Cell[0].dend[59](0.0555556)
# Segment coordinates:  -1.5462495278409782 -44.2971094829526 -20.5
# Cell[0].dend[59](0.166667)
# Segment coordinates:  5.432988089018932 -48.396975098187056 -21.0
# Cell[0].dend[59](0.277778)
# Segment coordinates:  12.33699590604753 -50.44981174966334 -18.5
# Cell[0].dend[59](0.388889)
# Segment coordinates:  19.72745487208363 -48.58000183105469 -17.0
# Cell[0].dend[59](0.5)
# Segment coordinates:  27.041377015219368 -46.657680275025534 -17.0
# Cell[0].dend[59](0.611111)
# Segment coordinates:  34.11787177051756 -46.895575001470284 -16.5
# Cell[0].dend[59](0.722222)
# Segment coordinates:  42.03633982226196 -48.04728038633108 -17.5
# Cell[0].dend[59](0.833333)
# Segment coordinates:  50.07663315724615 -50.81618925960578 -17.5
# Cell[0].dend[59](0.944444)
# Segment coordinates:  57.44930646494926 -54.81889852474416 -17.5
# Cell[0].dend[53](0.25)
# Segment coordinates:  -15.38058447261898 12.88670293136747 -17.776469870657692
# Cell[0].dend[53](0.75)
# Segment coordinates:  -17.454338917753645 15.440310461635132 -17.695774305950252
# Cell[0].dend[51](0.125)
# Segment coordinates:  -9.16140403294898 19.269422232470752 -18.0
# Cell[0].dend[51](0.375)
# Segment coordinates:  -14.15769198252824 22.289112905664627 -18.5
# Cell[0].dend[51](0.625)
# Segment coordinates:  -17.894206781877017 27.47993524347443 -18.5
# Cell[0].dend[51](0.875)
# Segment coordinates:  -19.991026223835917 32.3622150788986 -16.5
# Cell[0].dend[1](0.25)
# Segment coordinates:  -5.237413067037547 23.916936460049513 -17.0
# Cell[0].dend[1](0.75)
# Segment coordinates:  -9.433117197593763 28.115213321368643 -17.0
# Cell[0].dend[45](0.166667)
# Segment coordinates:  -14.028374739445017 28.113796690419164 -17.5
# Cell[0].dend[45](0.5)
# Segment coordinates:  -19.86606634827925 26.96938563062092 -16.5
# Cell[0].dend[45](0.833333)
# Segment coordinates:  -25.770028411630882 25.03392701640222 -16.0
# Cell[0].dend[49](0.25)
# Segment coordinates:  -29.42911154768806 26.425777993857075 -16.0
# Cell[0].dend[49](0.75)
# Segment coordinates:  -27.68522117311839 29.78129955747112 -16.5
# Cell[0].dend[46](0.125)
# Segment coordinates:  -32.23486152110432 22.1475464991749 -16.0
# Cell[0].dend[46](0.375)
# Segment coordinates:  -39.26994986517308 18.994010439154415 -17.0
# Cell[0].dend[46](0.625)
# Segment coordinates:  -45.918222011900795 15.322676049370264 -16.0
# Cell[0].dend[46](0.875)
# Segment coordinates:  -53.792933070937124 13.432866877653794 -16.0
# Cell[0].dend[48](0.0833333)
# Segment coordinates:  -60.114050733597715 9.859029110135022 -15.5
# Cell[0].dend[48](0.25)
# Segment coordinates:  -68.12453916601189 6.92939358150063 -15.5
# Cell[0].dend[48](0.416667)
# Segment coordinates:  -76.08711528184374 8.414053647585503 -15.0
# Cell[0].dend[48](0.583333)
# Segment coordinates:  -83.30439852323488 7.3919857874934785 -15.0
# Cell[0].dend[48](0.75)
# Segment coordinates:  -91.62858616247112 6.634858550278827 -14.0
# Cell[0].dend[48](0.916667)
# Segment coordinates:  -99.06999969482422 3.3991910852020797 -14.0
# Cell[0].dend[47](0.166667)
# Segment coordinates:  -59.08009975564126 13.377476052910977 -15.5
# Cell[0].dend[47](0.5)
# Segment coordinates:  -61.69880066128955 16.798363394048636 -16.5
# Cell[0].dend[47](0.833333)
# Segment coordinates:  -65.12548573707359 19.654531967571955 -16.0
# Cell[0].dend[2](0.25)
# Segment coordinates:  -12.835814268373031 32.74656481230721 -17.42951505174188
# Cell[0].dend[2](0.75)
# Segment coordinates:  -14.180001258850096 38.310683979941814 -16.5
# Cell[0].dend[28](0.166667)
# Segment coordinates:  -14.285066641376691 43.398668823838534 -15.422977022613537
# Cell[0].dend[28](0.5)
# Segment coordinates:  -9.276225213509985 46.808111091515485 -15.0
# Cell[0].dend[28](0.833333)
# Segment coordinates:  -5.77116994883861 51.40117170703421 -15.5
# Cell[0].dend[42](0.166667)
# Segment coordinates:  -0.533683956761663 52.362092341043294 -15.5
# Cell[0].dend[42](0.5)
# Segment coordinates:  5.6076357788908595 52.07938326547573 -15.75256943216343
# Cell[0].dend[42](0.833333)
# Segment coordinates:  11.618128896186597 50.84053464229004 -15.5
# Cell[0].dend[44](0.5)
# Segment coordinates:  16.49924707946831 51.37005561329562 -16.0
# Cell[0].dend[43](0.5)
# Segment coordinates:  16.134039642522218 49.31441300968676 -16.0
# Cell[0].dend[29](0.5)
# Segment coordinates:  -3.2696256484341992 54.62715147377487 -15.5
# Cell[0].dend[41](0.125)
# Segment coordinates:  0.5255651279545669 56.61623570257803 -16.0
# Cell[0].dend[41](0.375)
# Segment coordinates:  6.847722056323377 58.69144887540201 -15.0
# Cell[0].dend[41](0.625)
# Segment coordinates:  13.677710809303147 60.60525720952867 -14.752557638463554
# Cell[0].dend[41](0.875)
# Segment coordinates:  19.284104194285334 62.97756032227035 -15.5
# Cell[0].dend[30](0.25)
# Segment coordinates:  -4.027710602160619 58.052468316355345 -15.15361714265583
# Cell[0].dend[30](0.75)
# Segment coordinates:  -3.8938970918452 63.63067166466117 -15.5
# Cell[0].dend[36](0.5)
# Segment coordinates:  -5.994409107499615 67.91547794566937 -15.5
# Cell[0].dend[38](0.5)
# Segment coordinates:  -8.874730213310402 69.08399630767443 -15.0
# Cell[0].dend[40](0.5)
# Segment coordinates:  -10.875552989064325 69.01777311725739 -15.0
# Cell[0].dend[39](0.5)
# Segment coordinates:  -10.643556511436408 67.96899650013654 -15.0
# Cell[0].dend[37](0.1)
# Segment coordinates:  -8.094067625289423 72.9272894679898 -15.5
# Cell[0].dend[37](0.3)
# Segment coordinates:  -11.880091824232949 78.57551848202417 -16.0
# Cell[0].dend[37](0.5)
# Segment coordinates:  -16.09617710513409 83.31640934035076 -15.138237161506424
# Cell[0].dend[37](0.7)
# Segment coordinates:  -18.56685610146383 89.64856896038145 -15.27142700643891
# Cell[0].dend[37](0.9)
# Segment coordinates:  -19.194825974764232 96.24907391262762 -15.5
# Cell[0].dend[31](0.125)
# Segment coordinates:  -2.4403602651378913 69.4538739802653 -16.0
# Cell[0].dend[31](0.375)
# Segment coordinates:  -0.08590498949850041 76.75903788001106 -16.0
# Cell[0].dend[31](0.625)
# Segment coordinates:  -0.23832891360509284 84.02932035206732 -15.541794323088551
# Cell[0].dend[31](0.875)
# Segment coordinates:  -0.3599424066289717 91.08613641861373 -17.0
# Cell[0].dend[33](0.5)
# Segment coordinates:  0.018461169707790416 95.45586858354648 -16.5
# Cell[0].dend[35](0.25)
# Segment coordinates:  -1.87733717170337 96.8403112451396 -16.5
# Cell[0].dend[35](0.75)
# Segment coordinates:  -4.343388776207401 96.51335033435899 -16.5
# Cell[0].dend[34](0.25)
# Segment coordinates:  -0.505484121551828 98.31446290855774 -16.863575729282736
# Cell[0].dend[34](0.75)
# Segment coordinates:  0.46062459620749996 100.87083466448263 -17.5
# Cell[0].dend[32](0.1)
# Segment coordinates:  4.923196759286112 95.79760286184903 -16.5
# Cell[0].dend[32](0.3)
# Segment coordinates:  11.93313103137117 98.48450323417184 -17.0
# Cell[0].dend[32](0.5)
# Segment coordinates:  19.844155351458987 99.96971126555422 -16.5
# Cell[0].dend[32](0.7)
# Segment coordinates:  27.995679635978185 100.12996421977743 -17.0
# Cell[0].dend[32](0.9)
# Segment coordinates:  35.41423138394477 100.39585008589646 -16.5
# Cell[0].dend[3](0.25)
# Segment coordinates:  -17.027253371115425 43.305062825014176 -17.0
# Cell[0].dend[3](0.75)
# Segment coordinates:  -21.067300246491982 46.45516420707061 -16.546818081287146
# Cell[0].dend[21](0.166667)
# Segment coordinates:  -21.55871579608304 52.05009265479837 -15.5
# Cell[0].dend[21](0.5)
# Segment coordinates:  -22.739074578757915 59.27359569047775 -15.5
# Cell[0].dend[21](0.833333)
# Segment coordinates:  -23.50131703875309 67.01378673053476 -16.0
# Cell[0].dend[27](0.166667)
# Segment coordinates:  -23.30685859768186 72.41829084809733 -15.5
# Cell[0].dend[27](0.5)
# Segment coordinates:  -19.93187501679425 76.84655586923495 -15.5
# Cell[0].dend[27](0.833333)
# Segment coordinates:  -15.889289900272821 80.9946891656682 -15.5
# Cell[0].dend[22](0.166667)
# Segment coordinates:  -26.926300996656288 72.92618605586543 -15.5
# Cell[0].dend[22](0.5)
# Segment coordinates:  -31.54597862809645 77.81223963959313 -15.5
# Cell[0].dend[22](0.833333)
# Segment coordinates:  -34.78610622179107 83.00661542636531 -16.0
# Cell[0].dend[26](0.1)
# Segment coordinates:  -34.58474937159089 88.03331846332111 -16.0
# Cell[0].dend[26](0.3)
# Segment coordinates:  -34.06079186113925 94.46791379874108 -15.5
# Cell[0].dend[26](0.5)
# Segment coordinates:  -32.44871885873282 100.1388526094473 -17.0
# Cell[0].dend[26](0.7)
# Segment coordinates:  -30.494470097356174 105.9477146214441 -16.5
# Cell[0].dend[26](0.9)
# Segment coordinates:  -27.595688055631904 111.86963246166744 -18.0
# Cell[0].dend[23](0.125)
# Segment coordinates:  -40.148430005521476 87.0017678271889 -16.0
# Cell[0].dend[23](0.375)
# Segment coordinates:  -43.37034997451368 92.29802139660922 -16.5
# Cell[0].dend[23](0.625)
# Segment coordinates:  -45.604437917401604 98.15865400865795 -16.5
# Cell[0].dend[23](0.875)
# Segment coordinates:  -47.54563456522523 104.45352316629611 -17.0
# Cell[0].dend[25](0.125)
# Segment coordinates:  -44.991310631312444 109.92018000632413 -17.0
# Cell[0].dend[25](0.375)
# Segment coordinates:  -41.087721831498314 115.92189622259843 -17.0
# Cell[0].dend[25](0.625)
# Segment coordinates:  -39.56525437185455 121.83695370077174 -19.0
# Cell[0].dend[25](0.875)
# Segment coordinates:  -36.34653337576481 127.54733696125503 -20.0
# Cell[0].dend[24](0.166667)
# Segment coordinates:  -49.377496736859285 109.04732604316672 -17.0
# Cell[0].dend[24](0.5)
# Segment coordinates:  -51.29845228476769 113.18351948826042 -17.5
# Cell[0].dend[24](0.833333)
# Segment coordinates:  -55.516220577960446 116.47747871123622 -17.5
# Cell[0].dend[4](0.25)
# Segment coordinates:  -25.472356384557898 48.4340426407211 -16.0
# Cell[0].dend[4](0.75)
# Segment coordinates:  -31.10406687498483 49.44331494534225 -15.5
# Cell[0].dend[12](0.166667)
# Segment coordinates:  -36.21939064440738 47.713433373844396 -15.5
# Cell[0].dend[12](0.5)
# Segment coordinates:  -41.656984732274154 45.54167709510948 -15.5
# Cell[0].dend[12](0.833333)
# Segment coordinates:  -47.31331145088829 44.90689806037564 -15.0
# Cell[0].dend[16](0.166667)
# Segment coordinates:  -52.80800657561208 45.70097668736189 -15.0
# Cell[0].dend[16](0.5)
# Segment coordinates:  -58.59059476473218 46.24414994178433 -15.0
# Cell[0].dend[16](0.833333)
# Segment coordinates:  -64.32932372973197 46.090470856718014 -15.0
# Cell[0].dend[20](0.125)
# Segment coordinates:  -67.49818129388852 42.51954826252569 -15.5
# Cell[0].dend[20](0.375)
# Segment coordinates:  -70.67232601026213 36.50358806425547 -16.0
# Cell[0].dend[20](0.625)
# Segment coordinates:  -75.10954380581116 31.631654988985304 -15.499999999999998
# Cell[0].dend[20](0.875)
# Segment coordinates:  -79.72775621189359 27.15772862582174 -15.0
# Cell[0].dend[17](0.166667)
# Segment coordinates:  -69.14375063720301 45.23318765529646 -14.506641855758053
# Cell[0].dend[17](0.5)
# Segment coordinates:  -74.09987631551833 45.34943621443852 -14.5
# Cell[0].dend[17](0.833333)
# Segment coordinates:  -78.8713458343972 45.096849276875886 -14.5
# Cell[0].dend[19](0.25)
# Segment coordinates:  -81.50575465413138 47.37712782668774 -14.458895148430022
# Cell[0].dend[19](0.75)
# Segment coordinates:  -85.25699282704743 52.35602097698814 -14.5
# Cell[0].dend[18](0.25)
# Segment coordinates:  -81.83901034384515 42.3444691222956 -14.5
# Cell[0].dend[18](0.75)
# Segment coordinates:  -84.2432856589393 39.729826555963534 -14.5
# Cell[0].dend[13](0.166667)
# Segment coordinates:  -51.5710366411203 42.62991808787662 -15.5
# Cell[0].dend[13](0.5)
# Segment coordinates:  -53.30667745155034 38.361015324692275 -15.0
# Cell[0].dend[13](0.833333)
# Segment coordinates:  -54.55782131424942 33.511549145171145 -15.5
# Cell[0].dend[15](0.166667)
# Segment coordinates:  -57.698357305357135 30.151644983461225 -15.5
# Cell[0].dend[15](0.5)
# Segment coordinates:  -60.34000015258789 26.174079108624472 -15.5
# Cell[0].dend[15](0.833333)
# Segment coordinates:  -61.39952182853567 21.472436066241983 -15.5
# Cell[0].dend[14](0.25)
# Segment coordinates:  -58.132073946662246 32.79105997166153 -15.0
# Cell[0].dend[14](0.75)
# Segment coordinates:  -59.36094236635873 35.210818631765164 -15.5
# Cell[0].dend[5](0.125)
# Segment coordinates:  -35.48778762582893 53.01910911525534 -15.0
# Cell[0].dend[5](0.375)
# Segment coordinates:  -39.73761008971743 59.506625701855874 -14.058283049396838
# Cell[0].dend[5](0.625)
# Segment coordinates:  -46.83443329031711 63.49243598836922 -14.500000000000002
# Cell[0].dend[5](0.875)
# Segment coordinates:  -53.44285830025833 68.08588002197087 -15.0
# Cell[0].dend[11](0.25)
# Segment coordinates:  -57.38832084013343 68.84304099767054 -16.0
# Cell[0].dend[11](0.75)
# Segment coordinates:  -60.96171362803433 65.54012974158293 -16.5
# Cell[0].dend[6](0.5)
# Segment coordinates:  -56.54897748653321 72.14139960287238 -16.0
# Cell[0].dend[10](0.166667)
# Segment coordinates:  -59.34743601016016 73.84058402780278 -16.0
# Cell[0].dend[10](0.5)
# Segment coordinates:  -63.89243513961389 72.62669466005205 -16.5
# Cell[0].dend[10](0.833333)
# Segment coordinates:  -68.8921083113097 72.85646950074327 -16.5
# Cell[0].dend[7](0.166667)
# Segment coordinates:  -55.81891256857097 75.7297851496342 -16.0
# Cell[0].dend[7](0.5)
# Segment coordinates:  -55.84679189802179 80.43279835113776 -15.5
# Cell[0].dend[7](0.833333)
# Segment coordinates:  -56.4648509157099 85.30712242962885 -16.0
# Cell[0].dend[9](0.25)
# Segment coordinates:  -55.13883554850961 88.44141657221904 -16.5
# Cell[0].dend[9](0.75)
# Segment coordinates:  -52.82219461478289 90.65255978977319 -17.0
# Cell[0].dend[8](0.1)
# Segment coordinates:  -59.55989562925879 89.87783138137337 -16.0
# Cell[0].dend[8](0.3)
# Segment coordinates:  -62.83821120752938 94.45709662168038 -17.5
# Cell[0].dend[8](0.5)
# Segment coordinates:  -68.34726144329356 98.43779544424766 -18.0
# Cell[0].dend[8](0.7)
# Segment coordinates:  -73.77520046511088 101.01751863736833 -20.0
# Cell[0].dend[8](0.9)
# Segment coordinates:  -80.28249067646775 103.94070963229093 -20.5
# Cell[0].dend[106](0.25)
# Segment coordinates:  22.299602753968465 -2.242561310164453 -14.928256759984226
# Cell[0].dend[106](0.75)
# Segment coordinates:  24.136002820203736 -2.965264049919787 -16.0
# Cell[0].dend[112](0.25)
# Segment coordinates:  28.689465098531592 -2.110446757744631 -16.5
# Cell[0].dend[112](0.75)
# Segment coordinates:  35.71076485661099 -1.00479331967012 -16.0
# Cell[0].dend[114](0.25)
# Segment coordinates:  40.39062068874715 0.9819193011304361 -16.0
# Cell[0].dend[114](0.75)
# Segment coordinates:  43.25860159618782 2.2790495791530017 -16.5
# Cell[0].dend[118](0.1)
# Segment coordinates:  46.08934549163045 5.6075285304760705 -17.0
# Cell[0].dend[118](0.3)
# Segment coordinates:  51.36851922679048 9.824655197606694 -17.5
# Cell[0].dend[118](0.5)
# Segment coordinates:  56.7665055805181 13.116699172275267 -19.0
# Cell[0].dend[118](0.7)
# Segment coordinates:  61.864934466175036 17.514509364794485 -20.0
# Cell[0].dend[118](0.9)
# Segment coordinates:  65.1779380799678 23.381902846259656 -20.0
# Cell[0].dend[115](0.25)
# Segment coordinates:  46.032410391907646 1.374179815660977 -16.851640273310615
# Cell[0].dend[115](0.75)
# Segment coordinates:  49.03638983287658 -0.32666539402805983 -17.5
# Cell[0].dend[117](0.125)
# Segment coordinates:  52.87465370568832 -3.7499244258395787 -18.0
# Cell[0].dend[117](0.375)
# Segment coordinates:  55.2586972478081 -9.044837774313763 -17.5
# Cell[0].dend[117](0.625)
# Segment coordinates:  61.6311064079912 -10.736231845012174 -17.5
# Cell[0].dend[117](0.875)
# Segment coordinates:  65.13015214615939 -14.287655827465903 -19.5
# Cell[0].dend[116](0.0833333)
# Segment coordinates:  51.794679297692866 2.8936991967504966 -18.112716550323782
# Cell[0].dend[116](0.25)
# Segment coordinates:  57.081136539693276 8.490458390190133 -20.0
# Cell[0].dend[116](0.416667)
# Segment coordinates:  63.89416148635196 12.194072023016457 -20.5
# Cell[0].dend[116](0.583333)
# Segment coordinates:  69.20838889415663 19.058884430819244 -20.5
# Cell[0].dend[116](0.75)
# Segment coordinates:  75.40345623978409 24.49792481849876 -19.5
# Cell[0].dend[116](0.916667)
# Segment coordinates:  82.36716000789205 29.269558247861823 -19.0
# Cell[0].dend[113](0.0833333)
# Segment coordinates:  41.0433398555661 -2.66752345978968 -16.0
# Cell[0].dend[113](0.25)
# Segment coordinates:  44.66563886322674 -8.193882689257215 -17.0
# Cell[0].dend[113](0.416667)
# Segment coordinates:  47.148270919075664 -13.516318529991203 -17.5
# Cell[0].dend[113](0.583333)
# Segment coordinates:  51.794563611437226 -19.00575127654362 -18.0
# Cell[0].dend[113](0.75)
# Segment coordinates:  57.0221211778926 -24.27155168754641 -18.0
# Cell[0].dend[113](0.916667)
# Segment coordinates:  61.20803754188251 -30.721667819185313 -18.0
# Cell[0].dend[107](0.25)
# Segment coordinates:  25.387016096847375 -4.242144529161395 -17.0
# Cell[0].dend[107](0.75)
# Segment coordinates:  25.83593692169722 -6.827869814791164 -17.0
# Cell[0].dend[109](0.5)
# Segment coordinates:  27.623970931279178 -8.961679413667262 -17.5
# Cell[0].dend[111](0.25)
# Segment coordinates:  31.386208541567516 -11.054132633097272 -16.51466941033921
# Cell[0].dend[111](0.75)
# Segment coordinates:  34.5900552313294 -16.111082365217563 -16.5
# Cell[0].dend[110](0.5)
# Segment coordinates:  30.20777666106028 -6.795997634253633 -17.5
# Cell[0].dend[108](0.5)
# Segment coordinates:  24.53202184739832 -9.817977756667219 -17.0
# Cell[0].dend[81](0.166667)
# Segment coordinates:  13.075095772611201 18.59267050483052 -15.5
# Cell[0].dend[81](0.5)
# Segment coordinates:  16.669595620050494 22.001449681567003 -16.0
# Cell[0].dend[81](0.833333)
# Segment coordinates:  19.89621024125769 25.857626898824797 -16.0
# Cell[0].dend[83](0.5)
# Segment coordinates:  23.53907048602712 28.638309822470255 -16.0
# Cell[0].dend[87](0.166667)
# Segment coordinates:  27.797779712371174 30.65711260945517 -16.0
# Cell[0].dend[87](0.5)
# Segment coordinates:  32.54057007746955 32.08689212438961 -16.5
# Cell[0].dend[87](0.833333)
# Segment coordinates:  37.03553417979579 33.71752681286268 -17.5
# Cell[0].dend[95](0.25)
# Segment coordinates:  42.90192434546313 34.985072369822305 -17.5
# Cell[0].dend[95](0.75)
# Segment coordinates:  49.36708739783079 35.843076515643425 -18.5
# Cell[0].dend[101](0.25)
# Segment coordinates:  54.25345422446987 35.02705157471449 -18.0
# Cell[0].dend[101](0.75)
# Segment coordinates:  57.0613090647166 33.929804916531005 -18.077299949829047
# Cell[0].dend[105](0.25)
# Segment coordinates:  59.65061401989335 33.636223288548344 -19.0
# Cell[0].dend[105](0.75)
# Segment coordinates:  62.29900419415261 34.073206621271765 -19.0
# Cell[0].dend[102](0.166667)
# Segment coordinates:  59.03902156230906 30.89710660889019 -20.5
# Cell[0].dend[102](0.5)
# Segment coordinates:  62.53581512784862 24.935102146506594 -21.0
# Cell[0].dend[102](0.833333)
# Segment coordinates:  65.5304551030008 18.47480439626129 -21.0
# Cell[0].dend[104](0.1)
# Segment coordinates:  70.54347764637969 14.252351986447314 -21.0
# Cell[0].dend[104](0.3)
# Segment coordinates:  76.01711170457685 10.614536375570498 -21.0
# Cell[0].dend[104](0.5)
# Segment coordinates:  82.63541116182358 9.60560458726488 -21.066145626497708
# Cell[0].dend[104](0.7)
# Segment coordinates:  85.96332384520952 4.28370591044199 -21.0
# Cell[0].dend[104](0.9)
# Segment coordinates:  92.29920329444381 1.5269321249812138 -20.5
# Cell[0].dend[103](0.25)
# Segment coordinates:  66.77728123832208 11.895357740770496 -20.5
# Cell[0].dend[103](0.75)
# Segment coordinates:  69.02532866448573 6.254184253345219 -20.5
# Cell[0].dend[96](0.25)
# Segment coordinates:  52.916330158766925 36.37093919863602 -18.0
# Cell[0].dend[96](0.75)
# Segment coordinates:  52.76422095962319 38.914008049332644 -18.0
# Cell[0].dend[98](0.166667)
# Segment coordinates:  53.08638298518454 42.40227077015628 -18.5
# Cell[0].dend[98](0.5)
# Segment coordinates:  54.72721179198274 46.99716196644667 -19.5
# Cell[0].dend[98](0.833333)
# Segment coordinates:  54.945624095911406 51.117207133548135 -18.0
# Cell[0].dend[100](0.1)
# Segment coordinates:  52.76949363289308 57.17013331558088 -18.5
# Cell[0].dend[100](0.3)
# Segment coordinates:  54.21040282664734 64.40178998910389 -18.0
# Cell[0].dend[100](0.5)
# Segment coordinates:  57.747028034796315 70.39005518602073 -17.5
# Cell[0].dend[100](0.7)
# Segment coordinates:  62.803005777847794 75.78665335582295 -17.0
# Cell[0].dend[100](0.9)
# Segment coordinates:  65.40616833807623 82.6892538105948 -17.5
# Cell[0].dend[99](0.166667)
# Segment coordinates:  56.801887800143604 55.89720672956754 -18.0
# Cell[0].dend[99](0.5)
# Segment coordinates:  59.79509902859482 61.788858869840716 -17.976510900205913
# Cell[0].dend[99](0.833333)
# Segment coordinates:  64.06793508503145 66.14989159836396 -17.5
# Cell[0].dend[97](0.166667)
# Segment coordinates:  54.96967739070592 40.678882666922306 -19.0
# Cell[0].dend[97](0.5)
# Segment coordinates:  59.41470895000704 42.9847750109174 -18.834407621036657
# Cell[0].dend[97](0.833333)
# Segment coordinates:  63.78137188572339 44.329937138145354 -17.95846678686798
# Cell[0].dend[88](0.125)
# Segment coordinates:  38.54475458255517 38.226574178864084 -17.5
# Cell[0].dend[88](0.375)
# Segment coordinates:  38.27805927917366 45.046120273807006 -17.5
# Cell[0].dend[88](0.625)
# Segment coordinates:  38.74682343955712 52.03566957999198 -17.5
# Cell[0].dend[88](0.875)
# Segment coordinates:  37.81091174981666 58.73012296055867 -17.830800981817294
# Cell[0].dend[90](0.25)
# Segment coordinates:  37.22182459230144 63.216351460541155 -18.89543968105182
# Cell[0].dend[90](0.75)
# Segment coordinates:  36.4577999060407 66.39571733187191 -18.5
# Cell[0].dend[94](0.125)
# Segment coordinates:  35.89891761335496 70.54724229203161 -17.5
# Cell[0].dend[94](0.375)
# Segment coordinates:  37.52189196637195 76.69077428117302 -17.5
# Cell[0].dend[94](0.625)
# Segment coordinates:  40.34333844420644 81.66634256025762 -16.5
# Cell[0].dend[94](0.875)
# Segment coordinates:  41.7049383362605 87.49291501041841 -16.0
# Cell[0].dend[91](0.166667)
# Segment coordinates:  33.101999117711806 69.69179177561743 -17.478943710984616
# Cell[0].dend[91](0.5)
# Segment coordinates:  29.93312001939653 75.60752358117378 -17.0
# Cell[0].dend[91](0.833333)
# Segment coordinates:  27.121957182142985 81.29829950563806 -17.0
# Cell[0].dend[93](0.1)
# Segment coordinates:  29.81056330420037 86.97379562913213 -17.0
# Cell[0].dend[93](0.3)
# Segment coordinates:  31.492552842048507 93.53813965118415 -16.286204394159995
# Cell[0].dend[93](0.5)
# Segment coordinates:  31.060001373291016 100.15293346293473 -15.5
# Cell[0].dend[93](0.7)
# Segment coordinates:  29.04435807465189 105.73904865884955 -16.5
# Cell[0].dend[93](0.9)
# Segment coordinates:  28.928932594985522 112.67625969363394 -16.5
# Cell[0].dend[92](0.25)
# Segment coordinates:  25.996737460309234 85.11112185683982 -17.5
# Cell[0].dend[92](0.75)
# Segment coordinates:  24.17980451259755 86.87679804319194 -17.5
# Cell[0].dend[89](0.166667)
# Segment coordinates:  40.78542492555398 63.87892777602134 -18.0
# Cell[0].dend[89](0.5)
# Segment coordinates:  45.78925969756402 67.80201283560865 -18.379191060636693
# Cell[0].dend[89](0.833333)
# Segment coordinates:  49.06179245681524 72.42745184727431 -18.458964749177444
# Cell[0].dend[84](0.166667)
# Segment coordinates:  24.842283939685274 32.816439890953184 -16.5
# Cell[0].dend[84](0.5)
# Segment coordinates:  23.466954509604438 37.63991784719663 -17.18724145738331
# Cell[0].dend[84](0.833333)
# Segment coordinates:  23.02760717778269 42.64723412760847 -17.5
# Cell[0].dend[86](0.25)
# Segment coordinates:  20.990112395146454 46.457485049151515 -16.5
# Cell[0].dend[86](0.75)
# Segment coordinates:  16.711176017488597 47.04414641390328 -16.5
# Cell[0].dend[85](0.25)
# Segment coordinates:  23.097187545888914 46.62628338960849 -17.0
# Cell[0].dend[85](0.75)
# Segment coordinates:  23.93491974342112 49.555638694397004 -17.0
# Cell[0].dend[82](0.166667)
# Segment coordinates:  19.74847550472458 30.257957804632397 -16.5
# Cell[0].dend[82](0.5)
# Segment coordinates:  15.858174012677775 35.13306318603546 -16.0
# Cell[0].dend[82](0.833333)
# Segment coordinates:  12.40459443584736 40.11780450434789 -16.0
# Cell[0].AH(0.0625)
# Segment coordinates:  -1.1066110941495775 0.0 12.225458879237038
# Cell[0].AH(0.1875)
# Segment coordinates:  -4.746197542618961 0.0 15.614322554438127
# Cell[0].AH(0.3125)
# Segment coordinates:  -9.106488028457417 0.0 18.049019720744027
# Cell[0].AH(0.4375)
# Segment coordinates:  -13.737968602393993 0.0 19.927838041686616
# Cell[0].AH(0.5625)
# Segment coordinates:  -18.498065183283206 0.0 21.455367820092036
# Cell[0].AH(0.6875)
# Segment coordinates:  -23.32988406595923 0.0 22.739658009913384
# Cell[0].AH(0.8125)
# Segment coordinates:  -28.206520279019344 0.0 23.84238588749933
# Cell[0].AH(0.9375)
# Segment coordinates:  -33.113499438871 0.0 24.801547793445685
# Cell[0].SOCB(0.0625)
# Segment coordinates:  -38.04222031266252 0.0 25.64214885087138
# Cell[0].SOCB(0.1875)
# Segment coordinates:  -42.98716550994045 0.0 26.381536224985375
# Cell[0].SOCB(0.3125)
# Segment coordinates:  -47.9445767296899 0.0 27.032250946665336
# Cell[0].SOCB(0.4375)
# Segment coordinates:  -52.911766024744004 0.0 27.60365826323235
# Cell[0].SOCB(0.5625)
# Segment coordinates:  -57.88673425358158 0.0 28.102908754598253
# Cell[0].SOCB(0.6875)
# Segment coordinates:  -62.86794239161466 0.0 28.53555836007959
# Cell[0].SOCB(0.8125)
# Segment coordinates:  -67.85416943649989 0.0 28.905969461644297
# Cell[0].SOCB(0.9375)
# Segment coordinates:  -72.8444199850251 0.0 29.217573086389415
# Cell[0].NR(0.0277778)
# Segment coordinates:  -77.83786068498705 0.0 29.47306618207424
# Cell[0].NR(0.0833333)
# Segment coordinates:  -82.83377504857802 0.0 29.67453372726375
# Cell[0].NR(0.138889)
# Segment coordinates:  -87.83153016720944 0.0 29.823551144517026
# Cell[0].NR(0.194444)
# Segment coordinates:  -92.83055277159707 0.0 29.92124369109252
# Cell[0].NR(0.25)
# Segment coordinates:  -97.83042356451159 0.0 29.94091033935547
# Cell[0].NR(0.305556)
# Segment coordinates:  -102.83042397285506 0.0 29.94091033935547
# Cell[0].NR(0.361111)
# Segment coordinates:  -107.83042438119853 0.0 29.94091033935547
# Cell[0].NR(0.416667)
# Segment coordinates:  -112.83042478954201 0.0 29.94091033935547
# Cell[0].NR(0.472222)
# Segment coordinates:  -117.83042519788548 0.0 29.94091033935547
# Cell[0].NR(0.527778)
# Segment coordinates:  -122.83042560622894 0.0 29.94091033935547
# Cell[0].NR(0.583333)
# Segment coordinates:  -127.83042601457241 0.0 29.94091033935547
# Cell[0].NR(0.638889)
# Segment coordinates:  -132.83042642291588 0.0 29.94091033935547
# Cell[0].NR(0.694444)
# Segment coordinates:  -137.83042683125936 0.0 29.94091033935547
# Cell[0].NR(0.75)
# Segment coordinates:  -142.83042723960278 0.0 29.94091033935547
# Cell[0].NR(0.805556)
# Segment coordinates:  -147.83042764794627 0.0 29.94091033935547
# Cell[0].NR(0.861111)
# Segment coordinates:  -152.83042805628975 0.0 29.94091033935547
# Cell[0].NR(0.916667)
# Segment coordinates:  -157.8304284646332 0.0 29.94091033935547
# Cell[0].NR(0.972222)
# Segment coordinates:  -162.8304288729767 0.0 29.94091033935547
# Cell[0].axon(0.000868056)
# Segment coordinates:  -167.83042919635773 0.0 29.94091033935547
# Cell[0].axon(0.00260417)
# Segment coordinates:  -172.8304294347763 0.0 29.94091033935547
# Cell[0].axon(0.00434028)
# Segment coordinates:  -177.83042967319489 0.0 29.94091033935547
# Cell[0].axon(0.00607639)
# Segment coordinates:  -182.83042991161346 0.0 29.94091033935547
# Cell[0].axon(0.0078125)
# Segment coordinates:  -187.83043015003204 0.0 29.94091033935547
# Cell[0].axon(0.00954861)
# Segment coordinates:  -192.83043038845062 0.0 29.94091033935547
# Cell[0].axon(0.0112847)
# Segment coordinates:  -197.8304306268692 0.0 29.94091033935547
# Cell[0].axon(0.0130208)
# Segment coordinates:  -202.83043086528778 0.0 29.94091033935547
# Cell[0].axon(0.0147569)
# Segment coordinates:  -207.83043110370636 0.0 29.94091033935547
# Cell[0].axon(0.0164931)
# Segment coordinates:  -212.83043134212494 0.0 29.94091033935547
# Cell[0].axon(0.0182292)
# Segment coordinates:  -217.83043158054352 0.0 29.94091033935547
# Cell[0].axon(0.0199653)
# Segment coordinates:  -222.8304318189621 0.0 29.94091033935547
# Cell[0].axon(0.0217014)
# Segment coordinates:  -227.83043205738068 0.0 29.94091033935547
# Cell[0].axon(0.0234375)
# Segment coordinates:  -232.83043229579926 0.0 29.94091033935547
# Cell[0].axon(0.0251736)
# Segment coordinates:  -237.83043253421783 0.0 29.94091033935547
# Cell[0].axon(0.0269097)
# Segment coordinates:  -242.8304327726364 0.0 29.94091033935547
# Cell[0].axon(0.0286458)
# Segment coordinates:  -247.830433011055 0.0 29.94091033935547
# Cell[0].axon(0.0303819)
# Segment coordinates:  -252.83043324947357 0.0 29.94091033935547
# Cell[0].axon(0.0321181)
# Segment coordinates:  -257.83043348789215 0.0 29.94091033935547
# Cell[0].axon(0.0338542)
# Segment coordinates:  -262.83043372631073 0.0 29.94091033935547
# Cell[0].axon(0.0355903)
# Segment coordinates:  -267.8304339647293 0.0 29.94091033935547
# Cell[0].axon(0.0373264)
# Segment coordinates:  -272.8304342031479 0.0 29.94091033935547
# Cell[0].axon(0.0390625)
# Segment coordinates:  -277.83043444156647 0.0 29.94091033935547
# Cell[0].axon(0.0407986)
# Segment coordinates:  -282.83043467998505 0.0 29.94091033935547
# Cell[0].axon(0.0425347)
# Segment coordinates:  -287.8304349184036 0.0 29.94091033935547
# Cell[0].axon(0.0442708)
# Segment coordinates:  -292.8304351568222 0.0 29.94091033935547
# Cell[0].axon(0.0460069)
# Segment coordinates:  -297.8304353952408 0.0 29.94091033935547
# Cell[0].axon(0.0477431)
# Segment coordinates:  -302.83043563365936 0.0 29.94091033935547
# Cell[0].axon(0.0494792)
# Segment coordinates:  -307.83043587207794 0.0 29.94091033935547
# Cell[0].axon(0.0512153)
# Segment coordinates:  -312.8304361104965 0.0 29.94091033935547
# Cell[0].axon(0.0529514)
# Segment coordinates:  -317.8304363489151 0.0 29.94091033935547
# Cell[0].axon(0.0546875)
# Segment coordinates:  -322.8304365873337 0.0 29.94091033935547
# Cell[0].axon(0.0564236)
# Segment coordinates:  -327.83043682575226 0.0 29.94091033935547
# Cell[0].axon(0.0581597)
# Segment coordinates:  -332.83043706417084 0.0 29.94091033935547
# Cell[0].axon(0.0598958)
# Segment coordinates:  -337.8304373025894 0.0 29.94091033935547
# Cell[0].axon(0.0616319)
# Segment coordinates:  -342.830437541008 0.0 29.94091033935547
# Cell[0].axon(0.0633681)
# Segment coordinates:  -347.8304377794266 0.0 29.94091033935547
# Cell[0].axon(0.0651042)
# Segment coordinates:  -352.83043801784515 0.0 29.94091033935547
# Cell[0].axon(0.0668403)
# Segment coordinates:  -357.83043825626373 0.0 29.94091033935547
# Cell[0].axon(0.0685764)
# Segment coordinates:  -362.8304384946823 0.0 29.94091033935547
# Cell[0].axon(0.0703125)
# Segment coordinates:  -367.8304387331009 0.0 29.94091033935547
# Cell[0].axon(0.0720486)
# Segment coordinates:  -372.83043897151947 0.0 29.94091033935547
# Cell[0].axon(0.0737847)
# Segment coordinates:  -377.83043920993805 0.0 29.94091033935547
# Cell[0].axon(0.0755208)
# Segment coordinates:  -382.8304394483566 0.0 29.94091033935547
# Cell[0].axon(0.0772569)
# Segment coordinates:  -387.8304396867752 0.0 29.94091033935547
# Cell[0].axon(0.0789931)
# Segment coordinates:  -392.8304399251938 0.0 29.94091033935547
# Cell[0].axon(0.0807292)
# Segment coordinates:  -397.83044016361237 0.0 29.94091033935547
# Cell[0].axon(0.0824653)
# Segment coordinates:  -402.83044040203094 0.0 29.94091033935547
# Cell[0].axon(0.0842014)
# Segment coordinates:  -407.8304406404495 0.0 29.94091033935547
# Cell[0].axon(0.0859375)
# Segment coordinates:  -412.8304408788681 0.0 29.94091033935547
# Cell[0].axon(0.0876736)
# Segment coordinates:  -417.8304411172867 0.0 29.94091033935547
# Cell[0].axon(0.0894097)
# Segment coordinates:  -422.83044135570526 0.0 29.94091033935547
# Cell[0].axon(0.0911458)
# Segment coordinates:  -427.83044159412384 0.0 29.94091033935547
# Cell[0].axon(0.0928819)
# Segment coordinates:  -432.8304418325424 0.0 29.94091033935547
# Cell[0].axon(0.0946181)
# Segment coordinates:  -437.830442070961 0.0 29.94091033935547
# Cell[0].axon(0.0963542)
# Segment coordinates:  -442.8304423093796 0.0 29.94091033935547
# Cell[0].axon(0.0980903)
# Segment coordinates:  -447.83044254779816 0.0 29.94091033935547
# Cell[0].axon(0.0998264)
# Segment coordinates:  -452.83044278621674 0.0 29.94091033935547
# Cell[0].axon(0.101562)
# Segment coordinates:  -457.8304430246353 0.0 29.94091033935547
# Cell[0].axon(0.103299)
# Segment coordinates:  -462.8304432630539 0.0 29.94091033935547
# Cell[0].axon(0.105035)
# Segment coordinates:  -467.8304435014725 0.0 29.94091033935547
# Cell[0].axon(0.106771)
# Segment coordinates:  -472.83044373989105 0.0 29.94091033935547
# Cell[0].axon(0.108507)
# Segment coordinates:  -477.83044397830963 0.0 29.94091033935547
# Cell[0].axon(0.110243)
# Segment coordinates:  -482.8304442167282 0.0 29.94091033935547
# Cell[0].axon(0.111979)
# Segment coordinates:  -487.8304444551468 0.0 29.94091033935547
# Cell[0].axon(0.113715)
# Segment coordinates:  -492.83044469356537 0.0 29.94091033935547
# Cell[0].axon(0.115451)
# Segment coordinates:  -497.83044493198395 0.0 29.94091033935547
# Cell[0].axon(0.117188)
# Segment coordinates:  -502.8304451704025 0.0 29.94091033935547
# Cell[0].axon(0.118924)
# Segment coordinates:  -507.8304454088211 0.0 29.94091033935547
# Cell[0].axon(0.12066)
# Segment coordinates:  -512.8304456472397 0.0 29.94091033935547
# Cell[0].axon(0.122396)
# Segment coordinates:  -517.8304458856583 0.0 29.94091033935547
# Cell[0].axon(0.124132)
# Segment coordinates:  -522.8304461240768 0.0 29.94091033935547
# Cell[0].axon(0.125868)
# Segment coordinates:  -527.8304463624954 0.0 29.94091033935547
# Cell[0].axon(0.127604)
# Segment coordinates:  -532.830446600914 0.0 29.94091033935547
# Cell[0].axon(0.12934)
# Segment coordinates:  -537.8304468393326 0.0 29.94091033935547
# Cell[0].axon(0.131076)
# Segment coordinates:  -542.8304470777512 0.0 29.94091033935547
# Cell[0].axon(0.132812)
# Segment coordinates:  -547.8304473161697 0.0 29.94091033935547
# Cell[0].axon(0.134549)
# Segment coordinates:  -552.8304475545883 0.0 29.94091033935547
# Cell[0].axon(0.136285)
# Segment coordinates:  -557.8304477930069 0.0 29.94091033935547
# Cell[0].axon(0.138021)
# Segment coordinates:  -562.8304480314255 0.0 29.94091033935547
# Cell[0].axon(0.139757)
# Segment coordinates:  -567.830448269844 0.0 29.94091033935547
# Cell[0].axon(0.141493)
# Segment coordinates:  -572.8304485082626 0.0 29.94091033935547
# Cell[0].axon(0.143229)
# Segment coordinates:  -577.8304487466812 0.0 29.94091033935547
# Cell[0].axon(0.144965)
# Segment coordinates:  -582.8304489850998 0.0 29.94091033935547
# Cell[0].axon(0.146701)
# Segment coordinates:  -587.8304492235184 0.0 29.94091033935547
# Cell[0].axon(0.148438)
# Segment coordinates:  -592.830449461937 0.0 29.94091033935547
# Cell[0].axon(0.150174)
# Segment coordinates:  -597.8304497003555 0.0 29.94091033935547
# Cell[0].axon(0.15191)
# Segment coordinates:  -602.8304499387741 0.0 29.94091033935547
# Cell[0].axon(0.153646)
# Segment coordinates:  -607.8304501771927 0.0 29.94091033935547
# Cell[0].axon(0.155382)
# Segment coordinates:  -612.8304504156113 0.0 29.94091033935547
# Cell[0].axon(0.157118)
# Segment coordinates:  -617.8304506540298 0.0 29.94091033935547
# Cell[0].axon(0.158854)
# Segment coordinates:  -622.8304508924484 0.0 29.94091033935547
# Cell[0].axon(0.16059)
# Segment coordinates:  -627.830451130867 0.0 29.94091033935547
# Cell[0].axon(0.162326)
# Segment coordinates:  -632.8304513692856 0.0 29.94091033935547
# Cell[0].axon(0.164062)
# Segment coordinates:  -637.8304516077042 0.0 29.94091033935547
# Cell[0].axon(0.165799)
# Segment coordinates:  -642.8304518461227 0.0 29.94091033935547
# Cell[0].axon(0.167535)
# Segment coordinates:  -647.8304520845413 0.0 29.94091033935547
# Cell[0].axon(0.169271)
# Segment coordinates:  -652.8304523229599 0.0 29.94091033935547
# Cell[0].axon(0.171007)
# Segment coordinates:  -657.8304525613785 0.0 29.94091033935547
# Cell[0].axon(0.172743)
# Segment coordinates:  -662.8304527997971 0.0 29.94091033935547
# Cell[0].axon(0.174479)
# Segment coordinates:  -667.8304530382156 0.0 29.94091033935547
# Cell[0].axon(0.176215)
# Segment coordinates:  -672.8304532766342 0.0 29.94091033935547
# Cell[0].axon(0.177951)
# Segment coordinates:  -677.8304535150528 0.0 29.94091033935547
# Cell[0].axon(0.179688)
# Segment coordinates:  -682.8304537534714 0.0 29.94091033935547
# Cell[0].axon(0.181424)
# Segment coordinates:  -687.83045399189 0.0 29.94091033935547
# Cell[0].axon(0.18316)
# Segment coordinates:  -692.8304542303085 0.0 29.94091033935547
# Cell[0].axon(0.184896)
# Segment coordinates:  -697.8304544687271 0.0 29.94091033935547
# Cell[0].axon(0.186632)
# Segment coordinates:  -702.8304547071457 0.0 29.94091033935547
# Cell[0].axon(0.188368)
# Segment coordinates:  -707.8304549455643 0.0 29.94091033935547
# Cell[0].axon(0.190104)
# Segment coordinates:  -712.8304551839828 0.0 29.94091033935547
# Cell[0].axon(0.19184)
# Segment coordinates:  -717.8304554224014 0.0 29.94091033935547
# Cell[0].axon(0.193576)
# Segment coordinates:  -722.83045566082 0.0 29.94091033935547
# Cell[0].axon(0.195312)
# Segment coordinates:  -727.8304558992386 0.0 29.94091033935547
# Cell[0].axon(0.197049)
# Segment coordinates:  -732.8304561376572 0.0 29.94091033935547
# Cell[0].axon(0.198785)
# Segment coordinates:  -737.8304563760757 0.0 29.94091033935547
# Cell[0].axon(0.200521)
# Segment coordinates:  -742.8304566144943 0.0 29.94091033935547
# Cell[0].axon(0.202257)
# Segment coordinates:  -747.8304568529129 0.0 29.94091033935547
# Cell[0].axon(0.203993)
# Segment coordinates:  -752.8304570913315 0.0 29.94091033935547
# Cell[0].axon(0.205729)
# Segment coordinates:  -757.8304573297501 0.0 29.94091033935547
# Cell[0].axon(0.207465)
# Segment coordinates:  -762.8304575681686 0.0 29.94091033935547
# Cell[0].axon(0.209201)
# Segment coordinates:  -767.8304578065872 0.0 29.94091033935547
# Cell[0].axon(0.210938)
# Segment coordinates:  -772.8304580450058 0.0 29.94091033935547
# Cell[0].axon(0.212674)
# Segment coordinates:  -777.8304582834244 0.0 29.94091033935547
# Cell[0].axon(0.21441)
# Segment coordinates:  -782.830458521843 0.0 29.94091033935547
# Cell[0].axon(0.216146)
# Segment coordinates:  -787.8304587602615 0.0 29.94091033935547
# Cell[0].axon(0.217882)
# Segment coordinates:  -792.8304589986801 0.0 29.94091033935547
# Cell[0].axon(0.219618)
# Segment coordinates:  -797.8304592370987 0.0 29.94091033935547
# Cell[0].axon(0.221354)
# Segment coordinates:  -802.8304594755173 0.0 29.94091033935547
# Cell[0].axon(0.22309)
# Segment coordinates:  -807.8304597139359 0.0 29.94091033935547
# Cell[0].axon(0.224826)
# Segment coordinates:  -812.8304599523544 0.0 29.94091033935547
# Cell[0].axon(0.226562)
# Segment coordinates:  -817.830460190773 0.0 29.94091033935547
# Cell[0].axon(0.228299)
# Segment coordinates:  -822.8304604291916 0.0 29.94091033935547
# Cell[0].axon(0.230035)
# Segment coordinates:  -827.8304606676102 0.0 29.94091033935547
# Cell[0].axon(0.231771)
# Segment coordinates:  -832.8304609060286 0.0 29.94091033935547
# Cell[0].axon(0.233507)
# Segment coordinates:  -837.8304611444473 0.0 29.94091033935547
# Cell[0].axon(0.235243)
# Segment coordinates:  -842.8304613828659 0.0 29.94091033935547
# Cell[0].axon(0.236979)
# Segment coordinates:  -847.8304616212845 0.0 29.94091033935547
# Cell[0].axon(0.238715)
# Segment coordinates:  -852.8304618597031 0.0 29.94091033935547
# Cell[0].axon(0.240451)
# Segment coordinates:  -857.8304620981216 0.0 29.94091033935547
# Cell[0].axon(0.242188)
# Segment coordinates:  -862.8304623365402 0.0 29.94091033935547
# Cell[0].axon(0.243924)
# Segment coordinates:  -867.8304625749588 0.0 29.94091033935547
# Cell[0].axon(0.24566)
# Segment coordinates:  -872.8304628133774 0.0 29.94091033935547
# Cell[0].axon(0.247396)
# Segment coordinates:  -877.830463051796 0.0 29.94091033935547
# Cell[0].axon(0.249132)
# Segment coordinates:  -882.8304632902145 0.0 29.94091033935547
# Cell[0].axon(0.250868)
# Segment coordinates:  -887.8304635286331 0.0 29.94091033935547
# Cell[0].axon(0.252604)
# Segment coordinates:  -892.8304637670516 0.0 29.94091033935547
# Cell[0].axon(0.25434)
# Segment coordinates:  -897.8304640054702 0.0 29.94091033935547
# Cell[0].axon(0.256076)
# Segment coordinates:  -902.8304642438886 0.0 29.94091033935547
# Cell[0].axon(0.257812)
# Segment coordinates:  -907.8304644823072 0.0 29.94091033935547
# Cell[0].axon(0.259549)
# Segment coordinates:  -912.8304647207259 0.0 29.94091033935547
# Cell[0].axon(0.261285)
# Segment coordinates:  -917.8304649591446 0.0 29.94091033935547
# Cell[0].axon(0.263021)
# Segment coordinates:  -922.8304651975632 0.0 29.94091033935547
# Cell[0].axon(0.264757)
# Segment coordinates:  -927.8304654359816 0.0 29.94091033935547
# Cell[0].axon(0.266493)
# Segment coordinates:  -932.8304656744003 0.0 29.94091033935547
# Cell[0].axon(0.268229)
# Segment coordinates:  -937.8304659128189 0.0 29.94091033935547
# Cell[0].axon(0.269965)
# ...
# Cell[0].axon(0.679688)
# Segment coordinates:  -2122.830522418022 0.0 29.94091033935547
# Cell[0].axon(0.681424)
# Segment coordinates:  -2127.8305226564403 0.0 29.94091033935547
# Cell[0].axon(0.68316)
# Segment coordinates:  -2132.8305228948593 0.0 29.94091033935547
# Cell[0].axon(0.684896)
# Segment coordinates:  -2137.830523133278 0.0 29.94091033935547
# Cell[0].axon(0.686632)
# Segment coordinates:  -2142.8305233716965 0.0 29.94091033935547
# Cell[0].axon(0.688368)
# Segment coordinates:  -2147.8305236101146 0.0 29.94091033935547
# Cell[0].axon(0.690104)
# Segment coordinates:  -2152.8305238485336 0.0 29.94091033935547
# Cell[0].axon(0.69184)
# Segment coordinates:  -2157.830524086952 0.0 29.94091033935547
# Cell[0].axon(0.693576)
# Segment coordinates:  -2162.830524325371 0.0 29.94091033935547
# Cell[0].axon(0.695312)
# Segment coordinates:  -2167.8305245637894 0.0 29.94091033935547
# Cell[0].axon(0.697049)
# Segment coordinates:  -2172.830524802208 0.0 29.94091033935547
# Cell[0].axon(0.698785)
# Segment coordinates:  -2177.8305250406265 0.0 29.94091033935547
# Cell[0].axon(0.700521)
# Segment coordinates:  -2182.830525279045 0.0 29.94091033935547
# Cell[0].axon(0.702257)
# Segment coordinates:  -2187.8305255174637 0.0 29.94091033935547
# Cell[0].axon(0.703993)
# Segment coordinates:  -2192.8305257558823 0.0 29.94091033935547
# Cell[0].axon(0.705729)
# Segment coordinates:  -2197.830525994301 0.0 29.94091033935547
# Cell[0].axon(0.707465)
# Segment coordinates:  -2202.830526232719 0.0 29.94091033935547
# Cell[0].axon(0.709201)
# Segment coordinates:  -2207.830526471138 0.0 29.94091033935547
# Cell[0].axon(0.710938)
# Segment coordinates:  -2212.8305267095566 0.0 29.94091033935547
# Cell[0].axon(0.712674)
# Segment coordinates:  -2217.830526947975 0.0 29.94091033935547
# Cell[0].axon(0.71441)
# Segment coordinates:  -2222.8305271863937 0.0 29.94091033935547
# Cell[0].axon(0.716146)
# Segment coordinates:  -2227.8305274248123 0.0 29.94091033935547
# Cell[0].axon(0.717882)
# Segment coordinates:  -2232.830527663231 0.0 29.94091033935547
# Cell[0].axon(0.719618)
# Segment coordinates:  -2237.8305279016495 0.0 29.94091033935547
# Cell[0].axon(0.721354)
# Segment coordinates:  -2242.830528140068 0.0 29.94091033935547
# Cell[0].axon(0.72309)
# Segment coordinates:  -2247.830528378486 0.0 29.94091033935547
# Cell[0].axon(0.724826)
# Segment coordinates:  -2252.830528616905 0.0 29.94091033935547
# Cell[0].axon(0.726562)
# Segment coordinates:  -2257.830528855324 0.0 29.94091033935547
# Cell[0].axon(0.728299)
# Segment coordinates:  -2262.8305290937424 0.0 29.94091033935547
# Cell[0].axon(0.730035)
# Segment coordinates:  -2267.830529332161 0.0 29.94091033935547
# Cell[0].axon(0.731771)
# Segment coordinates:  -2272.8305295705795 0.0 29.94091033935547
# Cell[0].axon(0.733507)
# Segment coordinates:  -2277.830529808998 0.0 29.94091033935547
# Cell[0].axon(0.735243)
# Segment coordinates:  -2282.8305300474167 0.0 29.94091033935547
# Cell[0].axon(0.736979)
# Segment coordinates:  -2287.8305302858353 0.0 29.94091033935547
# Cell[0].axon(0.738715)
# Segment coordinates:  -2292.8305305242534 0.0 29.94091033935547
# Cell[0].axon(0.740451)
# Segment coordinates:  -2297.8305307626724 0.0 29.94091033935547
# Cell[0].axon(0.742188)
# Segment coordinates:  -2302.8305310010905 0.0 29.94091033935547
# Cell[0].axon(0.743924)
# Segment coordinates:  -2307.8305312395096 0.0 29.94091033935547
# Cell[0].axon(0.74566)
# Segment coordinates:  -2312.830531477928 0.0 29.94091033935547
# Cell[0].axon(0.747396)
# Segment coordinates:  -2317.8305317163467 0.0 29.94091033935547
# Cell[0].axon(0.749132)
# Segment coordinates:  -2322.8305319547653 0.0 29.94091033935547
# Cell[0].axon(0.750868)
# Segment coordinates:  -2327.830532193184 0.0 29.94091033935547
# Cell[0].axon(0.752604)
# Segment coordinates:  -2332.8305324316025 0.0 29.94091033935547
# Cell[0].axon(0.75434)
# Segment coordinates:  -2337.8305326700206 0.0 29.94091033935547
# Cell[0].axon(0.756076)
# Segment coordinates:  -2342.8305329084396 0.0 29.94091033935547
# Cell[0].axon(0.757812)
# Segment coordinates:  -2347.8305331468578 0.0 29.94091033935547
# Cell[0].axon(0.759549)
# Segment coordinates:  -2352.830533385277 0.0 29.94091033935547
# Cell[0].axon(0.761285)
# Segment coordinates:  -2357.8305336236954 0.0 29.94091033935547
# Cell[0].axon(0.763021)
# Segment coordinates:  -2362.830533862114 0.0 29.94091033935547
# Cell[0].axon(0.764757)
# Segment coordinates:  -2367.8305341005325 0.0 29.94091033935547
# Cell[0].axon(0.766493)
# Segment coordinates:  -2372.830534338951 0.0 29.94091033935547
# Cell[0].axon(0.768229)
# Segment coordinates:  -2377.8305345773697 0.0 29.94091033935547
# Cell[0].axon(0.769965)
# Segment coordinates:  -2382.8305348157883 0.0 29.94091033935547
# Cell[0].axon(0.771701)
# Segment coordinates:  -2387.830535054207 0.0 29.94091033935547
# Cell[0].axon(0.773438)
# Segment coordinates:  -2392.830535292625 0.0 29.94091033935547
# Cell[0].axon(0.775174)
# Segment coordinates:  -2397.830535531044 0.0 29.94091033935547
# Cell[0].axon(0.77691)
# Segment coordinates:  -2402.8305357694617 0.0 29.94091033935547
# Cell[0].axon(0.778646)
# Segment coordinates:  -2407.830536007881 0.0 29.94091033935547
# Cell[0].axon(0.780382)
# Segment coordinates:  -2412.8305362462997 0.0 29.94091033935547
# Cell[0].axon(0.782118)
# Segment coordinates:  -2417.8305364847183 0.0 29.94091033935547
# Cell[0].axon(0.783854)
# Segment coordinates:  -2422.830536723137 0.0 29.94091033935547
# Cell[0].axon(0.78559)
# Segment coordinates:  -2427.830536961555 0.0 29.94091033935547
# Cell[0].axon(0.787326)
# Segment coordinates:  -2432.830537199974 0.0 29.94091033935547
# Cell[0].axon(0.789062)
# Segment coordinates:  -2437.8305374383926 0.0 29.94091033935547
# Cell[0].axon(0.790799)
# Segment coordinates:  -2442.830537676811 0.0 29.94091033935547
# Cell[0].axon(0.792535)
# Segment coordinates:  -2447.8305379152293 0.0 29.94091033935547
# Cell[0].axon(0.794271)
# Segment coordinates:  -2452.8305381536484 0.0 29.94091033935547
# Cell[0].axon(0.796007)
# Segment coordinates:  -2457.830538392067 0.0 29.94091033935547
# Cell[0].axon(0.797743)
# Segment coordinates:  -2462.8305386304855 0.0 29.94091033935547
# Cell[0].axon(0.799479)
# Segment coordinates:  -2467.830538868904 0.0 29.94091033935547
# Cell[0].axon(0.801215)
# Segment coordinates:  -2472.8305391073222 0.0 29.94091033935547
# Cell[0].axon(0.802951)
# Segment coordinates:  -2477.830539345741 0.0 29.94091033935547
# Cell[0].axon(0.804688)
# Segment coordinates:  -2482.83053958416 0.0 29.94091033935547
# Cell[0].axon(0.806424)
# Segment coordinates:  -2487.8305398225784 0.0 29.94091033935547
# Cell[0].axon(0.80816)
# Segment coordinates:  -2492.830540060997 0.0 29.94091033935547
# Cell[0].axon(0.809896)
# Segment coordinates:  -2497.8305402994156 0.0 29.94091033935547
# Cell[0].axon(0.811632)
# Segment coordinates:  -2502.830540537834 0.0 29.94091033935547
# Cell[0].axon(0.813368)
# Segment coordinates:  -2507.8305407762527 0.0 29.94091033935547
# Cell[0].axon(0.815104)
# Segment coordinates:  -2512.8305410146713 0.0 29.94091033935547
# Cell[0].axon(0.81684)
# Segment coordinates:  -2517.83054125309 0.0 29.94091033935547
# Cell[0].axon(0.818576)
# Segment coordinates:  -2522.8305414915085 0.0 29.94091033935547
# Cell[0].axon(0.820312)
# Segment coordinates:  -2527.8305417299266 0.0 29.94091033935547
# Cell[0].axon(0.822049)
# Segment coordinates:  -2532.8305419683456 0.0 29.94091033935547
# Cell[0].axon(0.823785)
# Segment coordinates:  -2537.830542206764 0.0 29.94091033935547
# Cell[0].axon(0.825521)
# Segment coordinates:  -2542.830542445183 0.0 29.94091033935547
# Cell[0].axon(0.827257)
# Segment coordinates:  -2547.8305426836014 0.0 29.94091033935547
# Cell[0].axon(0.828993)
# Segment coordinates:  -2552.83054292202 0.0 29.94091033935547
# Cell[0].axon(0.830729)
# Segment coordinates:  -2557.8305431604385 0.0 29.94091033935547
# Cell[0].axon(0.832465)
# Segment coordinates:  -2562.830543398857 0.0 29.94091033935547
# Cell[0].axon(0.834201)
# Segment coordinates:  -2567.8305436372757 0.0 29.94091033935547
# Cell[0].axon(0.835938)
# Segment coordinates:  -2572.8305438756943 0.0 29.94091033935547
# Cell[0].axon(0.837674)
# Segment coordinates:  -2577.830544114113 0.0 29.94091033935547
# Cell[0].axon(0.83941)
# Segment coordinates:  -2582.830544352531 0.0 29.94091033935547
# Cell[0].axon(0.841146)
# Segment coordinates:  -2587.83054459095 0.0 29.94091033935547
# Cell[0].axon(0.842882)
# Segment coordinates:  -2592.8305448293686 0.0 29.94091033935547
# Cell[0].axon(0.844618)
# Segment coordinates:  -2597.830545067787 0.0 29.94091033935547
# Cell[0].axon(0.846354)
# Segment coordinates:  -2602.8305453062057 0.0 29.94091033935547
# Cell[0].axon(0.84809)
# Segment coordinates:  -2607.8305455446243 0.0 29.94091033935547
# Cell[0].axon(0.849826)
# Segment coordinates:  -2612.830545783043 0.0 29.94091033935547
# Cell[0].axon(0.851562)
# Segment coordinates:  -2617.8305460214615 0.0 29.94091033935547
# Cell[0].axon(0.853299)
# Segment coordinates:  -2622.83054625988 0.0 29.94091033935547
# Cell[0].axon(0.855035)
# Segment coordinates:  -2627.830546498298 0.0 29.94091033935547
# Cell[0].axon(0.856771)
# Segment coordinates:  -2632.830546736717 0.0 29.94091033935547
# Cell[0].axon(0.858507)
# Segment coordinates:  -2637.830546975136 0.0 29.94091033935547
# Cell[0].axon(0.860243)
# Segment coordinates:  -2642.8305472135544 0.0 29.94091033935547
# Cell[0].axon(0.861979)
# Segment coordinates:  -2647.830547451973 0.0 29.94091033935547
# Cell[0].axon(0.863715)
# Segment coordinates:  -2652.8305476903915 0.0 29.94091033935547
# Cell[0].axon(0.865451)
# Segment coordinates:  -2657.83054792881 0.0 29.94091033935547
# Cell[0].axon(0.867188)
# Segment coordinates:  -2662.8305481672287 0.0 29.94091033935547
# Cell[0].axon(0.868924)
# Segment coordinates:  -2667.8305484056473 0.0 29.94091033935547
# Cell[0].axon(0.87066)
# Segment coordinates:  -2672.830548644066 0.0 29.94091033935547
# Cell[0].axon(0.872396)
# Segment coordinates:  -2677.830548882484 0.0 29.94091033935547
# Cell[0].axon(0.874132)
# Segment coordinates:  -2682.830549120903 0.0 29.94091033935547
# Cell[0].axon(0.875868)
# Segment coordinates:  -2687.8305493593216 0.0 29.94091033935547
# Cell[0].axon(0.877604)
# Segment coordinates:  -2692.83054959774 0.0 29.94091033935547
# Cell[0].axon(0.87934)
# Segment coordinates:  -2697.8305498361588 0.0 29.94091033935547
# Cell[0].axon(0.881076)
# Segment coordinates:  -2702.8305500745773 0.0 29.94091033935547
# Cell[0].axon(0.882812)
# Segment coordinates:  -2707.8305503129955 0.0 29.94091033935547
# Cell[0].axon(0.884549)
# Segment coordinates:  -2712.8305505514145 0.0 29.94091033935547
# Cell[0].axon(0.886285)
# Segment coordinates:  -2717.830550789833 0.0 29.94091033935547
# Cell[0].axon(0.888021)
# Segment coordinates:  -2722.8305510282516 0.0 29.94091033935547
# Cell[0].axon(0.889757)
# Segment coordinates:  -2727.83055126667 0.0 29.94091033935547
# Cell[0].axon(0.891493)
# Segment coordinates:  -2732.830551505089 0.0 29.94091033935547
# Cell[0].axon(0.893229)
# Segment coordinates:  -2737.8305517435074 0.0 29.94091033935547
# Cell[0].axon(0.894965)
# Segment coordinates:  -2742.8305519819255 0.0 29.94091033935547
# Cell[0].axon(0.896701)
# Segment coordinates:  -2747.8305522203445 0.0 29.94091033935547
# Cell[0].axon(0.898438)
# Segment coordinates:  -2752.8305524587627 0.0 29.94091033935547
# Cell[0].axon(0.900174)
# Segment coordinates:  -2757.8305526971817 0.0 29.94091033935547
# Cell[0].axon(0.90191)
# Segment coordinates:  -2762.8305529356003 0.0 29.94091033935547
# Cell[0].axon(0.903646)
# Segment coordinates:  -2767.8305531740184 0.0 29.94091033935547
# Cell[0].axon(0.905382)
# Segment coordinates:  -2772.8305534124374 0.0 29.94091033935547
# Cell[0].axon(0.907118)
# Segment coordinates:  -2777.8305536508556 0.0 29.94091033935547
# Cell[0].axon(0.908854)
# Segment coordinates:  -2782.8305538892746 0.0 29.94091033935547
# Cell[0].axon(0.91059)
# Segment coordinates:  -2787.830554127693 0.0 29.94091033935547
# Cell[0].axon(0.912326)
# Segment coordinates:  -2792.8305543661118 0.0 29.94091033935547
# Cell[0].axon(0.914062)
# Segment coordinates:  -2797.83055460453 0.0 29.94091033935547
# Cell[0].axon(0.915799)
# Segment coordinates:  -2802.8305548429485 0.0 29.94091033935547
# Cell[0].axon(0.917535)
# Segment coordinates:  -2807.8305550813675 0.0 29.94091033935547
# Cell[0].axon(0.919271)
# Segment coordinates:  -2812.830555319786 0.0 29.94091033935547
# Cell[0].axon(0.921007)
# Segment coordinates:  -2817.8305555582047 0.0 29.94091033935547
# Cell[0].axon(0.922743)
# Segment coordinates:  -2822.8305557966232 0.0 29.94091033935547
# Cell[0].axon(0.924479)
# Segment coordinates:  -2827.830556035042 0.0 29.94091033935547
# Cell[0].axon(0.926215)
# Segment coordinates:  -2832.8305562734604 0.0 29.94091033935547
# Cell[0].axon(0.927951)
# Segment coordinates:  -2837.830556511879 0.0 29.94091033935547
# Cell[0].axon(0.929688)
# Segment coordinates:  -2842.830556750297 0.0 29.94091033935547
# Cell[0].axon(0.931424)
# Segment coordinates:  -2847.830556988716 0.0 29.94091033935547
# Cell[0].axon(0.93316)
# Segment coordinates:  -2852.830557227134 0.0 29.94091033935547
# Cell[0].axon(0.934896)
# Segment coordinates:  -2857.8305574655533 0.0 29.94091033935547
# Cell[0].axon(0.936632)
# Segment coordinates:  -2862.830557703972 0.0 29.94091033935547
# Cell[0].axon(0.938368)
# Segment coordinates:  -2867.8305579423904 0.0 29.94091033935547
# Cell[0].axon(0.940104)
# Segment coordinates:  -2872.830558180809 0.0 29.94091033935547
# Cell[0].axon(0.94184)
# Segment coordinates:  -2877.830558419227 0.0 29.94091033935547
# Cell[0].axon(0.943576)
# Segment coordinates:  -2882.830558657646 0.0 29.94091033935547
# Cell[0].axon(0.945312)
# Segment coordinates:  -2887.8305588960648 0.0 29.94091033935547
# Cell[0].axon(0.947049)
# Segment coordinates:  -2892.8305591344833 0.0 29.94091033935547
# Cell[0].axon(0.948785)
# Segment coordinates:  -2897.8305593729015 0.0 29.94091033935547
# Cell[0].axon(0.950521)
# Segment coordinates:  -2902.83055961132 0.0 29.94091033935547
# Cell[0].axon(0.952257)
# Segment coordinates:  -2907.830559849739 0.0 29.94091033935547
# Cell[0].axon(0.953993)
# Segment coordinates:  -2912.8305600881577 0.0 29.94091033935547
# Cell[0].axon(0.955729)
# Segment coordinates:  -2917.8305603265762 0.0 29.94091033935547
# Cell[0].axon(0.957465)
# Segment coordinates:  -2922.830560564995 0.0 29.94091033935547
# Cell[0].axon(0.959201)
# Segment coordinates:  -2927.8305608034134 0.0 29.94091033935547
# Cell[0].axon(0.960938)
# Segment coordinates:  -2932.830561041832 0.0 29.94091033935547
# Cell[0].axon(0.962674)
# Segment coordinates:  -2937.8305612802505 0.0 29.94091033935547
# Cell[0].axon(0.96441)
# Segment coordinates:  -2942.8305615186687 0.0 29.94091033935547
# Cell[0].axon(0.966146)
# Segment coordinates:  -2947.8305617570877 0.0 29.94091033935547
# Cell[0].axon(0.967882)
# Segment coordinates:  -2952.8305619955063 0.0 29.94091033935547
# Cell[0].axon(0.969618)
# Segment coordinates:  -2957.830562233925 0.0 29.94091033935547
# Cell[0].axon(0.971354)
# Segment coordinates:  -2962.8305624723434 0.0 29.94091033935547
# Cell[0].axon(0.97309)
# Segment coordinates:  -2967.830562710762 0.0 29.94091033935547
# Cell[0].axon(0.974826)
# Segment coordinates:  -2972.8305629491806 0.0 29.94091033935547
# Cell[0].axon(0.976562)
# Segment coordinates:  -2977.8305631875987 0.0 29.94091033935547
# Cell[0].axon(0.978299)
# Segment coordinates:  -2982.8305634260178 0.0 29.94091033935547
# Cell[0].axon(0.980035)
# Segment coordinates:  -2987.8305636644363 0.0 29.94091033935547
# Cell[0].axon(0.981771)
# Segment coordinates:  -2992.830563902855 0.0 29.94091033935547
# Cell[0].axon(0.983507)
# Segment coordinates:  -2997.8305641412735 0.0 29.94091033935547
# Cell[0].axon(0.985243)
# Segment coordinates:  -3002.8305643796916 0.0 29.94091033935547
# Cell[0].axon(0.986979)
# Segment coordinates:  -3007.8305646181107 0.0 29.94091033935547
# Cell[0].axon(0.988715)
# Segment coordinates:  -3012.8305648565292 0.0 29.94091033935547
# Cell[0].axon(0.990451)
# Segment coordinates:  -3017.830565094948 0.0 29.94091033935547
# Cell[0].axon(0.992188)
# Segment coordinates:  -3022.830565333366 0.0 29.94091033935547
# Cell[0].axon(0.993924)
# Segment coordinates:  -3027.830565571785 0.0 29.94091033935547
# Cell[0].axon(0.99566)
# Segment coordinates:  -3032.830565810203 0.0 29.94091033935547
# Cell[0].axon(0.997396)
# Segment coordinates:  -3037.830566048622 0.0 29.94091033935547
# Cell[0].axon(0.999132)
# Segment coordinates:  -3042.8305662870407 0.0 29.94091033935547

# %% [markdown]
# ## Step 2: Setup electrical stimulus

# %%
### Most features of the stimulus are set up a struct (dict) called Stim 
Stim = {}

# temporal features of the sitmulus 
Stim['pulseShape'] = 'triphasic'
Stim['dt'] = .005 # units: [ms]
Stim['delay'] = 10 # units: [ms]
Stim['dur'] = 0.05 # units: [ms]
Stim['stop'] = 80 # units: [ms]
Stim['amp'] = 2.5 # units: [uA]

# calibration phase of the stimulus 
Stim['initDur'] = 50 # units: [ms]
Stim['initDt'] = 1 # units: [ms]
Stim['vInit'] = -70 # units: [mV] #TODO: Old is -70

# spatial features of the stimulus 
# --> specifically defining the electrode geometry 
Stim['electrodes'] = [[-10,0,40]] # units: [um] 
Stim['electrode_type'] = 'disk'
Stim['rhoExt'] = 1000 # Ohm*cm
Stim['elecDiam'] = 15 # um
Stim['polarity'] = -1 # anodic == 1; cathodic == -1 

Stim['pulseRatioTri'] = [-2/3,1,-1/3]
Stim['pulseRatioBi'] = [1,-1]
Stim['frequency'] = 10 # units: [Hz]

# %% [markdown]
# ## Step 3: Set up recording vectors in order to probe what happened

# %% [markdown]
# ### Current recording vectors at all segment compartments

# %%
# Let's record all capacitive and ionic currents, along with membrane voltage
data = {}
for section in RGC.section_list:
    data[section.name()] = {}
    for seg, i in zip(section,range(section.nseg)):
        # record membrane voltage
        data[section.name()]['vmem' + str(i)] = h.Vector().record(seg._ref_v)
        # record total transmembrane currents
        data[section.name()]['imem' + str(i)] = h.Vector().record(seg._ref_i_membrane)
        # record capacitive current
        data[section.name()]['icap' + str(i)] = h.Vector().record(seg._ref_i_cap)
        # record Na, K, and Ca currents
        data[section.name()]['ina' + str(i)] = h.Vector().record(seg._ref_ina)
        data[section.name()]['ik' + str(i)] = h.Vector().record(seg._ref_ik)
        data[section.name()]['ica' + str(i)] = h.Vector().record(seg._ref_ica)

# %%
# # Setup dictionary to capture iOut at all cell compartments
# iOut = {}
# h.cvode.use_fast_imem(True) # needed for i_membrane_ / extracellular recording
# for section in RGC.section_list:
#     iOut[section.name()] = {}
#     for seg, i in zip(section,range(section.nseg)):
#         iOut[section.name()]['imem' + str(i)] = h.Vector().record(seg._ref_i_membrane_)

# %% [markdown]
# ### Time vector

# %%
# set up recoring vector for time in the simulation 
t = h.Vector().record(h._ref_t)

# %% [markdown]
# ## Step 4: Apply stimulus to the cell! (Run only one cell below)

# %%
# First, decide if you want current clamp (visually-) or electrode 
#   current (extracellularly-) evoked spiking
stim_type = 'clamp' # 'clamp' or 'extra'

# %%
if stim_type == 'clamp':
    # Current clamp simulation
    h.init()
    h.v_init = -69.2 # Old = -70
    h.finitialize(h.v_init)
    h.fcurrent()
    h.dt = 0.005
    h.tstop = 40

    # # Create intracellular stimulus
    # CurrentClamp = h.IClamp(0.5,sec=RGC.cell.soma) # inject current to soma
    # # CurrentClamp = h.IClamp(1,sec=h.axon) # inject current to axon
    # CurrentClamp.delay= 1 # msec
    # CurrentClamp.dur= 0.15 # msec
    # CurrentClamp.amp= 3.9 # nA

    # Create intracellular stimulus
    CurrentClamp = h.IClamp(0.5,sec=RGC.cell.soma) # inject current to soma
    # CurrentClamp = h.IClamp(1,sec=h.axon) # inject current to axon
    CurrentClamp.delay= 10 # msec
    CurrentClamp.dur= 0.30 # msec
    CurrentClamp.amp= 4 # nA

    # run sim!
    h.run()
elif stim_type == 'extra':
    # Need to do this everytime the stimulus parameters are changed
    hf.setupTransferImpedance(Stim, RGC)

    # Play the stimulus into the cell, setting it up for stimulation
    Stim['amp'] = Stim['polarity']*Stim['amp']
    tsvec, isvec = hf.setupStimulus(Stim)
    isvec.play(h._ref_is_xtra, tsvec, 1) 

    # Initialization phase of the simulation 
    h.init()
    h.tstop = Stim['initDur']
    h.dt = Stim['initDt']
    h.finitialize(Stim['vInit'])
    h.continuerun(h.tstop)

    # Run the simulation 
    h.tstop = Stim['initDur'] + Stim['stop']
    h.steps_per_ms = int(1/Stim['dt'])
    h.dt = Stim['dt']
    h.continuerun(h.tstop)
    print('***** sim done *****')

# %% [markdown]
# ## Step 5: Visualize what happened

# %%
# Let's plot the membrane voltage at the middle of the axon
fig, ax1 = plt.subplots(1,1,figsize=(10,10))

# First, extract vmem from middle of soma
time = t 
soma_vmem = data['Cell[0].soma']['vmem4']
ax1.plot(time,soma_vmem)

# soma_ina = data['Cell[0].axon']['ina201']
# soma_ik = data['Cell[0].axon']['ik201']
# soma_ica = data['Cell[0].axon']['ica201']
# # soma_icap = data['Cell[0].axon']['icap201']
# # soma_imem = data['Cell[0].axon']['imem201']
# ax2.plot(time,soma_ina)
# ax2.plot(time,soma_ik)
# ax2.plot(time,soma_ica)
# # ax2.plot(time,soma_icap)
# ax2.plot(time,soma_imem)
ax1.set_ylim([-70,10])
ax1.set_xlim([9,16])
# ax2.set_xlim([10,20])

# save plot as pdf
plt.savefig("AP_success.pdf",format="pdf", bbox_inches="tight")

plt.show()

# %%
print(soma_vmem[-1])
# Out:
# -69.23987882635025
